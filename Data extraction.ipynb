# %%
from gapipy import Client
from datetime import timedelta
import pandas as pd

# %%
import re
from dotenv import load_dotenv
import os

# Load the environment variables from the .env file
load_dotenv()

# Access environment variables
api_key = os.getenv("G_ADVENTURES_KEY")

client = Client(application_key=api_key)

# %%
tour_dossier = client.tour_dossiers.get(24309)

# %% [markdown]
# # Understanding a tour dossier

# %% [markdown]
# Let us this as an example

# %%
tour_dossier = client.tour_dossiers.get(24309)

# %%
tour_dossier
# Out:
# <TourDossier: 24309>

# %% [markdown]
# The tour dossier can be used as a dictionary with following keys:
# - id: Tour ID
# - href: Rest API for the tour
# - name: Name of the tour
# - slug: A version of the name field that is more suitable for use inside of a URL. Typically this means: all lowercase letters, hyphens instead of spaces, special characters and very common words removed. Sometimes the name field will change, but the slug should remain the same in order to preserve existing URL structures.
# - product_line: A 1 to 10 character sequence for the |tour| associated with this product.
# - departures_start_date: The earliest start_date of a departure for which this dossier is valid.
# - departures_end_date: The latest start_date of a departure for which this dossier is valid.
# - description: A short description of this tour dossier.
# - details: A list of dictionaries describing the tour
# - categories: A list of dictionaries with all the categories of the trip inc Travel style, Service level and physical rating
# - geography: A dictionary containing details of the geography of the tour
# - images: A list of dictionaries containing image links including he map
# - site_links: Links to the g-adventures site - needed for affiliate link
#
# - __booking_companies__: List of companies you can book with
# - __structured_itineraries__: A list of available itineraries
# - __advertised_departures__: A list of gapipy.models
# - __tour__: A reference to the tour
# - __departures__: gapipy.query
# - __relationships__: List of gapipy.resources

# %% [markdown]
# Example:

# %%
tour_dossier.description
# Out:
# "From the intricate saris of Rajasthan to the beautiful symmetry of the Taj Mahal, this compact journey is a photographer's delight and the perfect introduction to India. You'll float past the ghats on the Ganges River to encounter the spiritual heart of Hinduism in Varanasi and get off the beaten path exploring carved stepwells and quaint temples in rural villages. With the perfect combination of included activities and free time to explore the nation's rich heritage, you're sure to be caught up in India's incredible tapestry of life."

# %% [markdown]
# Those in bold are a little more complicated and have been broken down below

# %% [markdown]
# ## booking_companies

# %% [markdown]
# A list of companies you can book with

# %%
tour_dossier.booking_companies
# Out:
# [<BookingCompany: 1 (stub)>]

# %%
tour_dossier.booking_companies[0]
# Out:
# <BookingCompany: 1 (stub)>

# %%
tour_dossier.booking_companies[0].to_dict()
# Out:
# {'id': '1', 'href': 'https://rest.gadventures.com/booking_companies/1'}

# %% [markdown]
# ## structured_itineraries

# %% [markdown]
# structured_itineraries contains a list of itineraries available for a tour dossier.

# %%
tour_dossier.structured_itineraries
# Out:
# [<Itinerary: 868 (stub)>, <Itinerary: 868 (stub)>]

# %% [markdown]
# An itinerary contains a structured representation of all activities, meals, transports, starting and finishing locations for a tour.

# %%
tour_dossier.structured_itineraries[0].variation_id
# Out:
# '3543'

# %% [markdown]
# structured_itineraries can be used as a dictionary with following keys:
# - id: the id of the tour dossier
# - variation_id: The unique identifier of a specific variation of this itinerary
# - href: Rest API for the itinerary can be accessed by - client.itineraries.get(868)
# - name: A name to help disambiguate between itineraries on the same tour
# - tour_dossier:A reference to the tour_dossier resource with which this itinerary is associated
# - booking_companies: The booking companies that provide this tour.
# - flags: A list of potential flags for a itinerary
# - duration: The length of the |tour| in days
# - start_location: The starting location of |tour|
# - end_location: The ending location of the |tour|
# - meals_included: Information about the number of meals included in the |tour|
# - meals_budget: Information about the budget for meals that are not included
# - details: List of details for the itinerary
# - packing_lists: List of dictionaries for packing list
# - images: List of image objects
# - media: gapipy.query
# - highlights: gapipy.query
# - valid_during_ranges: Dates the itinerary is valid for
# - variations: The different variations of this itinerary
# - __days__: A list on day objects accessed by .to_dict()
# - site_links: List of dictionaries for the tour - useful for
# - publish_state: The state or online status of this itinerary
# - ripple_score: The Ripple Score for an Itinerary. This is calculated based off the amount of money that stays locally. The score ranges between 0-100

# %% [markdown]
# Example:

# %%
tour_dossier.structured_itineraries[0].variation_id
# Out:
# '3543'

# %% [markdown]
# Days are a little more complicated and there is a lost of useful info so I've detailed it below

# %% [markdown]
# ### Days

# %% [markdown]
# days is a list of days within the itinerary

# %%
tour_dossier.structured_itineraries[0].days
# Out:
# [<ItineraryDay 1>,
#  <ItineraryDay 2>,
#  <ItineraryDay 3>,
#  <ItineraryDay 4>,
#  <ItineraryDay 5>,
#  <ItineraryDay 6>,
#  <ItineraryDay 7>,
#  <ItineraryDay 8>,
#  <ItineraryDay 9>,
#  <ItineraryDay 10>,
#  <ItineraryDay 11>,
#  <ItineraryDay 12>,
#  <ItineraryDay 13>,
#  <ItineraryDay 14>,
#  <ItineraryDay 15>]

# %% [markdown]
# A day contains a structured representation of all activities, meals, transports, starting and finishing locations for a days.

# %%
tour_dossier.structured_itineraries[0].days[0]
# Out:
# <ItineraryDay 1>

# %% [markdown]
# days can be used as a dictionary with following keys:
# - id: ID for the day
# - day: The day number within the itinerary
# - label: A location or activity based label for the day
# - summary: 	A summary description of the day
# - description: A detailed description of the day
# - instructions: Additional notes, instructions or tips about the day needed when on the trip
# - meals: Included meals for this day
# - start_location: The starting location of the day
# - end_location: The ending location of the day
# - __components__: A list of components (activities and transports) for the day
# - optional_activities: A list of optional activities for the day

# %% [markdown]
# Example:

# %%
tour_dossier.structured_itineraries[0].days[8].summary
# Out:
# "Enjoy a day trip to Khajuraho, where India's largest group of medieval temples reside, known for their Kama Sutra statues. Learn the history of these world-famous temples on a guided tour and enjoy a taste of a little erotica from the Middle Ages. After, opt to visit a nearby waterfall or watch an evening dance performance."

# %% [markdown]
# #### components

# %% [markdown]
# components are a list of components within a day of the itinerary

# %%
tour_dossier.structured_itineraries[0].days[8].components
# Out:
# [<ItineraryComponent: TRANSPORT>,
#  <ItineraryComponent: ACTIVITY>,
#  <ItineraryComponent: TRANSPORT>,
#  <ItineraryComponent: ACCOMMODATION>]

# %% [markdown]
# component contains a structured representation of the elements of a compontent.

# %%
tour_dossier.structured_itineraries[0].days[8].components[2]
# Out:
# <ItineraryComponent: TRANSPORT>

# %% [markdown]
# - type: TRANSPORT, ACTIVITY or ACCOMMODATION
# - summary: A summary of the component
# - description:
# - instructions:
# - distance_km:
# - start_time:
# - end_time:
# - time_period:
# - start_location: Link to the end location
# - end_location: Link to the start location
# - accommodation_dossier: The link to the dossier for the accommodation
# - activity_dossier: The link to the dossier for the activity
# - transport_dossier: The link to the dossier for the transport
# - duration: min and max duration of the component if there is one

# %% [markdown]
# Useful example

# %%
itinerary = tour_dossier.structured_itineraries[1]
{day.day: day.summary for day in itinerary.days}
# Out:
# {1: 'Arrive at any time. Arrival transfer included through the G Adventures-supported Women on Wheels project.',
#  2: 'Take a morning walk through the city with a young adult from the G Adventures-supported New Delhi Streetkids Project. Later, visit Old Delhi, explore the spice markets, and visit Jama Masjid and Connaught Place.',
#  3: "Arrive in Jaipur and explore this gorgeous 'pink city'.",
#  4: "Stop and take a photo of the 'Palace of the Winds' and wander the organized streets of the 'Pink City'. Later, enjoy a visit to the Amber Fort, famous for its mixture of Hindu and Muslim architecture.",
#  5: 'Visit this Rajasthani rural village in the beautiful countryside with a close tie to the land.',
#  6: 'Stop by the impressive Abhaneri stepwells on the way to Agra, home of the Taj Mahal.',
#  7: 'Visit the famous Taj Mahal, Baby Taj, and Agra Fort.',
#  8: 'Travel to Alipura and stay in a heritage property in the village.',
#  9: "Enjoy a day trip to Khajuraho to visit the Khajuraho Group of Monuments, India's largest group of medieval temples, known for their kama sutra statues.",
#  10: 'Visit Orchha, a quiet rural town along the banks of the Betwa River and enjoy a puja ceremony. Visit a unique paper-making plant en route, set up to assist tribal women from the area.',
#  11: 'Visit the Orchha Palace complex and enjoy free time before the overnight train to Varanasi. Opt for a local cooking class with a family.',
#  12: 'Take an orientation walk through the oldest continually inhabited city in the world. Marvel at the ghats from the River Ganges as you enjoy boat trips at sunrise and sunset.',
#  13: 'Watch the sunrise from a boat along the Ganges. Enjoy free time in this holy city.',
#  14: 'Cut out the travel time with an afternoon flight back to Delhi.',
#  15: 'Depart at any time.'}

# %% [markdown]
# ## advertised_departures

# %% [markdown]
# advertised_departures contains a list of sellable departures, segmented by currency. Each object will contain the associated departure, pricing, currency, room, and a relevant promotion if applicable. This field is useful for showing the lowest price of a trip.

# %%
tour_dossier.advertised_departures
# Out:
# [<gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f9755c75030>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a30d0>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a3130>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a2dd0>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a2fe0>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a3580>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a3400>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a3550>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a3610>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a2a70>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a36a0>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a3700>,
#  <gapipy.models.advertised_departure.AdvertisedDeparture at 0x7f97079a3760>]

# %%
tour_dossier.advertised_departures[7].to_dict()
# Out:
# {'previous_amount': None,
#  'currency': 'JPY',
#  'amount': '207000.00',
#  'room': None,
#  'departure': {'id': '1227042',
#   'href': 'https://rest.gadventures.com/departures/1227042'},
#  'promotion': None}

# %% [markdown]
# ## tour

# %% [markdown]
# a reference to the tour, available through:

# %%
tour_dossier.tour.to_dict()
# Out:
# {'id': 24309, 'href': 'https://rest.gadventures.com/tours/24309'}

# %% [markdown]
# ## departures

# %% [markdown]
# departures can be accessed individually

# %%
depart = client.departures.get(1080958)

# %% [markdown]
# or from the tour dossier

# %%
my_generator = tour_dossier.departures.all()

for value in my_generator:
    #print(value.sku, value.lowest_pp2a_prices[0].to_dict())
    break

# %% [markdown]
# - id: Departure ID
# - href: Departure reference
# - date_created: date the departure was created
# - date_last_modified: date teh departure was last modified
# - name: Tour name
# - product_line: tour product line
# - sku: refference number
# - start_date: tour start date
# - finish_date: tour end date
# - date_cancelled: the date the tour was cancelled
# - flags: A list of codes that, when present, require special considerations when booking a service on this departure.
# - latest_arrival_time: The latest time that the traveller’s flight can arrive at the nearest_start_airport for this product, in the standard dates-time.
# - earliest_departure_time: The earliest time that the traveller’s flight can depart at the nearest_finish_aiport for this product, in the standard dates-time.
# - nearest_start_airport: The nearest airport to the start location
# - nearest_finish_airport:The nearest airport to the end location
# - availability: Availability information for this option
# - requirements: A list of requirements that must be met before a service on this product can be booked or confirmed.
# - program: Generally referencing another tour code
# - booking_companies: A list of booking companies that own this product
# - start_address: Start Location information for the product.
# - finish_address: End Location information for the product.
# - tour: tour ID
# - tour_dossier: Tour dossier ID
# - __rooms__: A list of available rooming options
# - addons: A list of available add ons
# - lowest_pp2a_prices: The lowest Adult price per person (based on double occupancy) for this departure across all rooms,
# - local_payments: List of potential payment that need to be made in person
# - travel_ready_policy: The Travel Ready Policy associated with this Departure
# - components: a list of components associated with this departure
# - structured_itineraries: A list of itineraries for this departure
# - relationships: Relationships list the related departures that are available to be sold along side this departure.

# %% [markdown]
# ### rooms

# %% [markdown]
# a list of rooms available for the departure

# %%
depart.rooms
# Out:
# [<DepartureRoom (Standard)>]

# %% [markdown]
# that are used to access details around availability, cost and promotions

# %%
depart.rooms[0]
# Out:
# <DepartureRoom (Standard)>

# %% [markdown]
# - code: code of room type
# - name: name of room type
# - flags: a list of thing that need to be flagged
# - availability: details relating to availability
# - price_bands: a list of price bands, one for each currency that contains amounts and promotions
# - addons: available components that can be added

# %% [markdown]
# ## relationships

# %%
tour_dossier.relationships[0].to_dict()
# Out:
# {'type': 'MINI_ADVENTURE',
#  'sub_type': 'PRE_TOUR',
#  'tour_dossier': {'id': '25561',
#   'href': 'https://rest.gadventures.com/tour_dossiers/25561',
#   'product_line': 'RAHDDN'},
#  'valid_during_ranges': [{'start_date': '2021-04-01', 'end_date': None}]}

# %% [markdown]
# # other

# %% [markdown]
# # extract data for 1 departure

# %% [markdown]
# first departure in april 2024

# %%
filtered_departures = client.departures.filter(start_date="2024-04-01", )
filtered_departures.count()
# Out:
# 130

# %%
my_generator = filtered_departures.all()
departures_list = []
for value in my_generator:
    departures_list.append(value)
    break

# %%
first_departure = departures_list[0]

# %%
# tour name
tour_name = first_departure.tour_dossier.name

# %%
# tour url
tour_url = first_departure.tour_dossier.site_links[0]['href']

# %%
# tour categories list
categories_id_list = [i['id'] for i in first_departure.tour_dossier.categories]
categories_id_list
# Out:
# ['21', '30', '36', '131', '59']

# %%
# tour categories
tour_categories_dictionaries = {}

for category in first_departure.tour_dossier.categories:
    if category["category_type"]['label'] in tour_categories_dictionaries:
        tour_categories_dictionaries[category["category_type"]['label']] += category['name']
    else:
        tour_categories_dictionaries[category["category_type"]['label']] = category['name']
        
tour_categories_dictionaries
# Out:
# {'Travel Style': 'Classic',
#  'Service Level': 'Standard',
#  'Physical Grading': '3 - Average',
#  'Merchandising': 'Planeterra Project',
#  'Trip Type': 'Small Group'}

# %%
# tour geography
visited_countries_list = []
for country in first_departure.tour_dossier.geography['visited_countries']:
    visited_countries_list.append(country["name"])

# %%
# structured itinerary id
structured_itineraries_id_list = []
for i in first_departure.structured_itineraries:
    structured_itineraries_id_list.append(i.variation_id)

# %%
# departure start date
start_date = first_departure.start_date

# %%
from datetime import timedelta
# duration
duration = first_departure.finish_date - first_departure.start_date + timedelta(days=1)

# %%
# extract room name, price band and amount
room_name_list = []
price_bands_list = []
amount_list = []

for i in first_departure.rooms:
    data = i.to_dict()
    room_name_list.append(data["name"])
    
    for price_brand in data["price_bands"]:
        price_bands_list.append(price_brand["name"])
        
        for price in price_brand["prices"]:
            if price['currency'] == "GBP":
                amount_list.append(price['amount'])

# %%
dataframe_dictionary = {}
dataframe_dictionary['tour_name'] = [tour_name]
dataframe_dictionary['visited_countries'] = visited_countries_list
dataframe_dictionary['start_date'] = [start_date]
dataframe_dictionary['duration'] = [duration]
dataframe_dictionary['cost'] = amount_list
dataframe_dictionary['url'] = [tour_url]

# %%
dataframe_dictionary = dict(dataframe_dictionary, **tour_categories_dictionaries)

# %%
#text_data
itinerary = ''
itinerary += f"Name of the tour: {tour_name}\n"
itinerary += f'Countries visited: {"".join(visited_countries_list)}\n'
itinerary += f'Start date: {str(start_date)}\n'
itinerary += f'Trip duration: {str(duration)[:-9]}\n'
itinerary += f'Trip cost: £{"".join(amount_list)}\n'

# %%
for category in categories_id_list:
    category_dict = client.tour_categories.get(category).to_dict()
    itinerary += f"{category_dict['category_type']['name']}: {category_dict['name']} - {category_dict['description']}\n"

# %%
itinerary += 'Itinerary:\n'
itinerary_days = first_departure.structured_itineraries[0]
for day in itinerary_days.days:
    itinerary += f'Day {day.day}: {day.summary}\n'

# %%
print(itinerary)
# Out:
# Name of the tour: Iceland Northern Lights & Golden Circle
# Countries visited: Iceland
# Start date: 2024-04-01
# Trip duration: 5 days
# Trip cost: £1279.00
# Travel Style: Classic - All of the highlights, culture, access, and I-can’t-believe-we-did-that moments, all at a great price.
# Service Level: Standard - Comfortable tourist-class accommodations with character; mix of public and private transport.
# Physical Grading: 3 - Average - Some tours may include light hiking, biking, rafting, or kayaking in addition to walking.
# Merchandising: Planeterra Project - None
# Trip Type: Small Group - Group trips average 12 travellers per departure, depending on the adventure. The maximum is usually no more than 16, but some can be smaller or bigger, depending on the trip. Check individual trips for details.
# Itinerary:
# Day 1: Arrive at any time.
# Day 2: Travel from Reykjavík to explore a lava cave in the Bláfjöll Mountains. In the afternoon, get up close and personal with the famous Icelandic horse before returning to Álftröð. In the evening, you will have your first chance to see the Northern Lights out in the countryside.
# Day 3: Head to Þingvellir National Park. Visit sights like the Geysir Hot Spring and Gullfoss waterfall. In the evening, embrace your inner chef and prepare dinner together at the guesthouse. Afterwards, you will have another opportunity to try seeing the Northern Lights.
# Day 4: Travel to Sólheimajökull glacier and take some time to explore the area, or opt for a stunning hike. Drive the scenic southern coast and visit the Skógafoss and Seljalandsfoss waterfalls on the way back to Reykjavík.
# Day 5: Depart at any time.

# %%
with open(f'{tour_name} - {" ".join(structured_itineraries_id_list)}.txt', "w") as file:
    file.write(itinerary)

# %%
import pandas as pd
df = pd.DataFrame(dataframe_dictionary)
df
# Out:
#                                  tour_name visited_countries  start_date  \
# 0  Iceland Northern Lights & Golden Circle           Iceland  2024-04-01
#
#   duration     cost                                                url  \
# 0   5 days  1279.00  https://www.gadventures.com/trips/iceland-nort...
#
#   Travel Style Service Level Physical Grading       Merchandising    Trip Type
# 0      Classic      Standard      3 - Average  Planeterra Project  Small Group

# %% [markdown]
# # 3 from one days data

# %%
filtered_departures = client.departures.filter(start_date="2024-04-19")

# %%
filtered_departures.count()
# Out:
# 142

# %%
my_generator = filtered_departures.all()

# %%
departures_dictionaries_list = []
reference_count = 0
for value in my_generator:
    reference_count += 1
    if reference_count % 10 == 0:
        print(reference_count)
    try:
        if value.availability['status'] == "AVAILABLE" and value.tour_dossier != None: 
            print(value.id)
            trip_list = [category['name'] for category in value.tour_dossier.categories if category['category_type']['label'] ==  "Trip Type"]
            if 'Small Group' in trip_list:
                for i in range(len(value.structured_itineraries)):

                    # get tour name
                    tour_name = value.tour_dossier.name

                    # structured itinerary id
                    structured_itineraries_name = value.structured_itineraries[i].name

                    # get the list of countries visited
                    visited_countries_list = []
                    for country in value.tour_dossier.geography['visited_countries']:
                        visited_countries_list.append(country["name"])

                    # get start date
                    start_date = value.start_date

                    # get duration
                    duration = value.finish_date - value.start_date + timedelta(days=1)

                    # get pricing form room categories
                    room_categories_dictionaries = {}

                    for room in value.rooms:
                        data = room.to_dict()
                        for price_brand in data["price_bands"]:
                            for price in price_brand["prices"]:
                                if price['currency'] == "GBP":               
                                    if f'{data["name"]} - {price_brand["name"]}' in room_categories_dictionaries:
                                        room_categories_dictionaries[f'{data["name"]} - {price_brand["name"]}'] += price['amount']
                                    else:
                                        room_categories_dictionaries[f'{data["name"]} - {price_brand["name"]}'] = price['amount']

                    # get tour url 
                    tour_url = value.tour_dossier.site_links[0]['href']
                    
                    # get tour description
                    tour_description = value.tour_dossier.description

                    # get tour categories
                    categories_id_list = [i['id'] for i in value.tour_dossier.categories]

                    tour_categories_dictionaries = {}

                    for category in value.tour_dossier.categories:
                        if category["category_type"]['label'] in tour_categories_dictionaries:
                            tour_categories_dictionaries[category["category_type"]['label']] += ' ' + category['name']
                        else:
                            tour_categories_dictionaries[category["category_type"]['label']] = category['name']

                    # create dictionary
                    dataframe_dictionary = {}
                    dataframe_dictionary['tour_name'] = tour_name
                    dataframe_dictionary['itinerary_name'] = structured_itineraries_name
                    dataframe_dictionary['visited_countries'] = " ".join(visited_countries_list)
                    dataframe_dictionary['start_date'] = start_date
                    dataframe_dictionary['duration'] = duration
                    dataframe_dictionary['url'] = tour_url
                    dataframe_dictionary['tour_description'] = tour_description

                    # combine dictionaries
                    dataframe_dictionary = dict(dataframe_dictionary, **tour_categories_dictionaries, **room_categories_dictionaries)

                    # add full dict to list
                    departures_dictionaries_list.append(dataframe_dictionary)

                    # text file
                    itinerary = ''
                    itinerary += f"Name of the tour: {tour_name}\n"
                    itinerary += f'Countries visited: {" ".join(visited_countries_list)}\n'
                    itinerary += f'Trip duration: {str(duration)[:-9]}\n'

#                     for key, description in room_categories_dictionaries.items():
#                         itinerary += f'{key}: {description}\n'

                    for category in categories_id_list:
                        category_dict = client.tour_categories.get(category).to_dict()
                        itinerary += f"{category_dict['category_type']['name']}: {category_dict['name']} - {category_dict['description']}\n"


                    itinerary += 'Itinerary:\n'
                    itinerary_days = value.structured_itineraries[i]
                    for day in itinerary_days.days:
                        itinerary += f'Day {day.day}: {day.summary}\n'


                    with open(f'raw_data/itinerary_text/{tour_name} {structured_itineraries_name}.txt', "w") as file:
                        file.write(itinerary)

                    print(f'{tour_name} - {structured_itineraries_name} - {value.tour_dossier.id} - {len(value.structured_itineraries)}')
        
    except:
        print("403 issue")


        # ID: {value.tour_dossier.id}. Number of itineraries: {len(value.structured_itineraries)}
# Out:
# 1196464
# 403 issue
# 1198260
# Laos: Sunrises & Street Food -  - 24821 - 1
# 10
# 1200164
# Laos to Thailand: Night Markets & Mekong Cruising -  - 24823 - 1
# 1200263
# Laos to Northern Thailand: Treks & Trails -  - 25030 - 1
# 20
# 1206493
# 30
# 1207235
# 1207601
# 1208333
# 403 issue
# 403 issue
# 1209431
# 1209797
# 403 issue
# 1210529
# 40
# 1225257
# Everest Base Camp Trek -  - 22946 - 1
# 1225886
# Golden Triangle -  - 24213 - 1
# 50
# 1229178
# Maldives Dhoni Cruise -  - 21203 - 1
# 1229376
# Classic Bali -  - 22791 - 1
# 1229560
# Borneo – East Sabah Adventure -  - 24511 - 1
# 1229745
# Discover Japan -  - 22800 - 1
# 1229896
# Japan Express: Osaka to Tokyo -  - 22801 - 1
# 1230211
# Best of Cambodia & Northern Thailand -  - 25018 - 1
# 1231033
# Best of South Korea -  - 24992 - 1
# 60
# 1232424
# Highlights of Jordan -  - 22862 - 1
# 1232429
# Egypt & Jordan Adventure -  - 22854 - 1
# 1232430
# Best of Egypt -  - 22853 - 1
# 1232875
# Jordan Multisport -  - 23286 - 1
# 1233035
# Highlights of Morocco -  - 22844 - 1
# 1233345
# Coastal Morocco: Waves & Market Stalls -  - 25021 - 1
# 70
# 1235602
# 1235968
# 1236334
# 1236700
# 1237066
# 80
# 1237798
# 1238571
# 403 issue
# 1239586
# 1240318
# 1240685
# 1241051
# 90
# 1242668
# Southern Divide -  - 24266 - 1
# 1243048
# The Scenic Route - Lima to Buenos Aires -  - 23667 - 1
# 100
# 1247931
# Amazon to the Andes - Inca Trail - 22887 - 3
# Amazon to the Andes - Lares Trek - 22887 - 3
# Amazon to the Andes - Cusco Stay - 22887 - 3
# 1248271
# Inca Discovery Plus - Inca Trail - 22985 - 3
# Inca Discovery Plus - Lares Trek - 22985 - 3
# Inca Discovery Plus - Cusco Stay - 22985 - 3
# 1248611
# Inca Discovery - Inca Trail - 22984 - 3
# Inca Discovery - Lares Trek - 22984 - 3
# Inca Discovery - Cusco Stay - 22984 - 3
# 1248950
# The Inca Trail - Inca Trail - 22983 - 3
# The Inca Trail - Lares Trek - 22983 - 3
# The Inca Trail - Cusco Stay - 22983 - 3
# 1249289
# The Lares Trek - Lares Trek - 22398 - 2
# The Lares Trek - Cusco Stay - 22398 - 2
# 1249627
# 403 issue
# 110
# 1249964
# 403 issue
# 1250367
# Lima to La Paz: Sandboarding & Sunsets - Inca Trail - 23233 - 3
# Lima to La Paz: Sandboarding & Sunsets - Lares Trek - 23233 - 3
# Lima to La Paz: Sandboarding & Sunsets - Cusco Stay - 23233 - 3
# 1250557
# Lima to Buenos Aires: Deserts & Dancing - Inca Trail - 23263 - 3
# Lima to Buenos Aires: Deserts & Dancing - Lares Trek - 23263 - 3
# Lima to Buenos Aires: Deserts & Dancing - Cusco Stay - 23263 - 3
# 1252770
# Camino de Santiago Encompassed -  - 24855 - 1
# 1252954
# Spain & Portugal: Flamenco & Tapas -  - 23660 - 1
# 1252987
# Spain, Portugal & Morocco: Tapas, Medinas & Sunsets -  - 25259 - 1
# 1253377
# Best of Uzbekistan and Turkmenistan -  - 25027 - 1
# 1254347
# Ecuador: Amazon, Hot Springs & Volcanoes -  - 23761 - 1
# 120
# 1256198
# Mexico Coast-to-Coast: Puerto Vallarta to the Mayan Riviera -  - 25843 - 1
# 1256199
# Essential Central Mexico -  - 25837 - 1
# 1256294
# The Many Sides of Mexico: Puerto Vallarta to Oaxaca -  - 25842 - 1
# 1256816
# Lima to Rio: Coast to Coast - Inca Trail - 23264 - 3
# Lima to Rio: Coast to Coast - Lares Trek - 23264 - 3
# Lima to Rio: Coast to Coast - Cusco Stay - 23264 - 3
# 1258667
# Cambodia Experience -  - 22823 - 1
# 130
# 1261378
# Vietnam: Historic Cities & Halong Bay Cruising -  - 23394 - 1
# 1265395
# Best of Spain & Portugal -  - 22874 - 1
# 1265396
# Highlights of Portugal -  - 24776 - 1
# 1268798
# Cambodia to Vietnam: Night Markets & Noodle-Making -  - 23397 - 1
# 1268901
# Cambodia: Ancient Ruins & Boat Rides -  - 23376 - 1
# 1269224
# 140

# %%
df = pd.DataFrame(departures_dictionaries_list)
df.to_csv('raw_data/one_day_test.csv', index=False)
df
# Out:
#                                             tour_name itinerary_name  \
# 0                        Laos: Sunrises & Street Food
# 1   Laos to Thailand: Night Markets & Mekong Cruising
# 2           Laos to Northern Thailand: Treks & Trails
# 3                              Everest Base Camp Trek
# 4                                     Golden Triangle
# 5                               Maldives Dhoni Cruise
# 6                                        Classic Bali
# 7                       Borneo – East Sabah Adventure
# 8                                      Discover Japan
# 9                       Japan Express: Osaka to Tokyo
# 10               Best of Cambodia & Northern Thailand
# 11                                Best of South Korea
# 12                               Highlights of Jordan
# 13                           Egypt & Jordan Adventure
# 14                                      Best of Egypt
# 15                                  Jordan Multisport
# 16                              Highlights of Morocco
# 17             Coastal Morocco: Waves & Market Stalls
# 18                                    Southern Divide
# 19            The Scenic Route - Lima to Buenos Aires
# 20                                Amazon to the Andes     Inca Trail
# 21                                Amazon to the Andes     Lares Trek
# 22                                Amazon to the Andes     Cusco Stay
# 23                                Inca Discovery Plus     Inca Trail
# 24                                Inca Discovery Plus     Lares Trek
# 25                                Inca Discovery Plus     Cusco Stay
# 26                                     Inca Discovery     Inca Trail
# 27                                     Inca Discovery     Lares Trek
# 28                                     Inca Discovery     Cusco Stay
# 29                                     The Inca Trail     Inca Trail
# 30                                     The Inca Trail     Lares Trek
# 31                                     The Inca Trail     Cusco Stay
# 32                                     The Lares Trek     Lares Trek
# 33                                     The Lares Trek     Cusco Stay
# 34                     Trekking the Inca Trail: 5D/4N     Inca Trail
# 35                     Trekking the Inca Trail: 4D/3N     Inca Trail
# 36             Lima to La Paz: Sandboarding & Sunsets     Inca Trail
# 37             Lima to La Paz: Sandboarding & Sunsets     Lares Trek
# 38             Lima to La Paz: Sandboarding & Sunsets     Cusco Stay
# 39            Lima to Buenos Aires: Deserts & Dancing     Inca Trail
# 40            Lima to Buenos Aires: Deserts & Dancing     Lares Trek
# 41            Lima to Buenos Aires: Deserts & Dancing     Cusco Stay
# 42                     Camino de Santiago Encompassed
# 43                 Spain & Portugal: Flamenco & Tapas
# 44  Spain, Portugal & Morocco: Tapas, Medinas & Su...
# 45                Best of Uzbekistan and Turkmenistan
# 46           Ecuador: Amazon, Hot Springs & Volcanoes
# 47  Mexico Coast-to-Coast: Puerto Vallarta to the ...
# 48                           Essential Central Mexico
# 49  The Many Sides of Mexico: Puerto Vallarta to O...
# 50                        Lima to Rio: Coast to Coast     Inca Trail
# 51                        Lima to Rio: Coast to Coast     Lares Trek
# 52                        Lima to Rio: Coast to Coast     Cusco Stay
# 53                                Cambodia Experience
# 54     Vietnam: Historic Cities & Halong Bay Cruising
# 55                           Best of Spain & Portugal
# 56                             Highlights of Portugal
# 57  Cambodia to Vietnam: Night Markets & Noodle-Ma...
# 58               Cambodia: Ancient Ruins & Boat Rides
#
#                               visited_countries  start_date duration  \
# 0                                 Laos Thailand  2024-04-19   9 days
# 1                                 Laos Thailand  2024-04-19  11 days
# 2                                 Laos Thailand  2024-04-19  14 days
# 3                                         Nepal  2024-04-19  15 days
# 4                                         India  2024-04-19   8 days
# 5                                      Maldives  2024-04-19   7 days
# 6                                     Indonesia  2024-04-19   8 days
# 7                                      Malaysia  2024-04-19   8 days
# 8                                         Japan  2024-04-19  14 days
# 9                                         Japan  2024-04-19   9 days
# 10                    Vietnam Cambodia Thailand  2024-04-19  15 days
# 11                                  South Korea  2024-04-19   8 days
# 12                                       Jordan  2024-04-19   8 days
# 13                                 Jordan Egypt  2024-04-19  15 days
# 14                                        Egypt  2024-04-19   8 days
# 15                                       Jordan  2024-04-19   8 days
# 16                                      Morocco  2024-04-19  15 days
# 17                                      Morocco  2024-04-19   5 days
# 18                           Chile Bolivia Peru  2024-04-19  21 days
# 19                 Argentina Bolivia Chile Peru  2024-04-19  30 days
# 20                                         Peru  2024-04-19  12 days
# 21                                         Peru  2024-04-19  12 days
# 22                                         Peru  2024-04-19  12 days
# 23                                         Peru  2024-04-19   9 days
# 24                                         Peru  2024-04-19   9 days
# 25                                         Peru  2024-04-19   9 days
# 26                                         Peru  2024-04-19   8 days
# 27                                         Peru  2024-04-19   8 days
# 28                                         Peru  2024-04-19   8 days
# 29                                         Peru  2024-04-19   7 days
# 30                                         Peru  2024-04-19   7 days
# 31                                         Peru  2024-04-19   7 days
# 32                                         Peru  2024-04-19   7 days
# 33                                         Peru  2024-04-19   7 days
# 34                                         Peru  2024-04-19   5 days
# 35                                         Peru  2024-04-19   4 days
# 36                                 Bolivia Peru  2024-04-19  21 days
# 37                                 Bolivia Peru  2024-04-19  21 days
# 38                                 Bolivia Peru  2024-04-19  21 days
# 39                 Argentina Bolivia Chile Peru  2024-04-19  35 days
# 40                 Argentina Bolivia Chile Peru  2024-04-19  35 days
# 41                 Argentina Bolivia Chile Peru  2024-04-19  35 days
# 42                                        Spain  2024-04-19  10 days
# 43                               Spain Portugal  2024-04-19  10 days
# 44                       Morocco Spain Portugal  2024-04-19  16 days
# 45                      Turkmenistan Uzbekistan  2024-04-19  13 days
# 46                                      Ecuador  2024-04-19   9 days
# 47                                       Mexico  2024-04-19  22 days
# 48                                       Mexico  2024-04-19   9 days
# 49                                       Mexico  2024-04-19  15 days
# 50  Argentina Bolivia Brazil Chile Uruguay Peru  2024-04-19  51 days
# 51  Argentina Bolivia Brazil Chile Uruguay Peru  2024-04-19  51 days
# 52  Argentina Bolivia Brazil Chile Uruguay Peru  2024-04-19  51 days
# 53                    Vietnam Cambodia Thailand  2024-04-19   9 days
# 54                                      Vietnam  2024-04-19  12 days
# 55                               Spain Portugal  2024-04-19  14 days
# 56                                     Portugal  2024-04-19   7 days
# 57                    Vietnam Cambodia Thailand  2024-04-19  20 days
# 58                    Vietnam Cambodia Thailand  2024-04-19  10 days
#
#                                                   url  \
# 0   https://www.gadventures.com/trips/budget-laos-...
# 1   https://www.gadventures.com/trips/budget-tour-...
# 2   https://www.gadventures.com/trips/trekking-lao...
# 3   https://www.gadventures.com/trips/everest-base...
# 4   https://www.gadventures.com/trips/golden-trian...
# 5   https://www.gadventures.com/trips/maldives-dho...
# 6   https://www.gadventures.com/trips/classic-bali...
# 7   https://www.gadventures.com/trips/borneo-east-...
# 8   https://www.gadventures.com/trips/discover-jap...
# 9   https://www.gadventures.com/trips/japan-expres...
# 10  https://www.gadventures.com/trips/best-of-camb...
# 11  https://www.gadventures.com/trips/best-of-sout...
# 12  https://www.gadventures.com/trips/highlights-o...
# 13  https://www.gadventures.com/trips/egypt-and-jo...
# 14  https://www.gadventures.com/trips/best-of-egyp...
# 15  https://www.gadventures.com/trips/jordan-multi...
# 16  https://www.gadventures.com/trips/highlights-o...
# 17  https://www.gadventures.com/trips/tour-coastal...
# 18  https://www.gadventures.com/trips/southern-div...
# 19  https://www.gadventures.com/trips/the-scenic-r...
# 20  https://www.gadventures.com/trips/amazon-to-th...
# 21  https://www.gadventures.com/trips/amazon-to-th...
# 22  https://www.gadventures.com/trips/amazon-to-th...
# 23  https://www.gadventures.com/trips/inca-discove...
# 24  https://www.gadventures.com/trips/inca-discove...
# 25  https://www.gadventures.com/trips/inca-discove...
# 26  https://www.gadventures.com/trips/inca-discove...
# 27  https://www.gadventures.com/trips/inca-discove...
# 28  https://www.gadventures.com/trips/inca-discove...
# 29  https://www.gadventures.com/trips/the-inca-tra...
# 30  https://www.gadventures.com/trips/the-inca-tra...
# 31  https://www.gadventures.com/trips/the-inca-tra...
# 32  https://www.gadventures.com/trips/the-lares-tr...
# 33  https://www.gadventures.com/trips/the-lares-tr...
# 34  https://www.gadventures.com/trips/trekking-the...
# 35  https://www.gadventures.com/trips/trekking-the...
# 36  https://www.gadventures.com/trips/andes-tour--...
# 37  https://www.gadventures.com/trips/andes-tour--...
# 38  https://www.gadventures.com/trips/andes-tour--...
# 39  https://www.gadventures.com/trips/lima-tour-bu...
# 40  https://www.gadventures.com/trips/lima-tour-bu...
# 41  https://www.gadventures.com/trips/lima-tour-bu...
# 42  https://www.gadventures.com/trips/camino-de-sa...
# 43  https://www.gadventures.com/trips/budget-tour-...
# 44  https://www.gadventures.com/trips/spain-portug...
# 45  https://www.gadventures.com/trips/best-of-uzbe...
# 46  https://www.gadventures.com/trips/ecuador-amaz...
# 47  https://www.gadventures.com/trips/mexico-coast...
# 48  https://www.gadventures.com/trips/essential-ce...
# 49  https://www.gadventures.com/trips/many-sides-o...
# 50  https://www.gadventures.com/trips/lima-to-rio-...
# 51  https://www.gadventures.com/trips/lima-to-rio-...
# 52  https://www.gadventures.com/trips/lima-to-rio-...
# 53  https://www.gadventures.com/trips/cambodia-exp...
# 54  https://www.gadventures.com/trips/vietnam-budg...
# 55  https://www.gadventures.com/trips/best-of-spai...
# 56  https://www.gadventures.com/trips/portugal-hig...
# 57  https://www.gadventures.com/trips/budget-tour-...
# 58  https://www.gadventures.com/trips/budget-cambo...
#
#                                      tour_description  \
# 0   Now's the time for adventure on your terms wit...
# 1   Now's the time to explore Laos and Thailand on...
# 2   Now's the time to explore Laos and Thailand on...
# 3   Everest is more than a mountain and the journe...
# 4   This short but spicy Indian journey will intro...
# 5   White sands, blue skies, and crystal-clear wat...
# 6   From pristine beaches to temples surrounded by...
# 7   Between its intriguing wildlife, skyscraper-he...
# 8   From the towers and gadgets of Tokyo to the se...
# 9   From the Buddhist monks of Kōyasan to the high...
# 10  Ancient ruins, fascinating cultures, and bustl...
# 11  Ready for a unique travel experience? South Ko...
# 12  Explore ancient sights and lost cities, overni...
# 13  Get ready for a wide-ranging adventure showcas...
# 14  This journey through Egypt packs in awe-inspir...
# 15  Jordan is famed for its ancient past but its p...
# 16  If you want to hit Morocco’s highlights, this ...
# 17  Now's the time to explore Morocco on your term...
# 18  For those looking to experience the history, c...
# 19  Imagine an entire month (30 days, to be exact)...
# 20  This adventure offers up an intriguing combina...
# 21  This adventure offers up an intriguing combina...
# 22  This adventure offers up an intriguing combina...
# 23  Like our Inca Discovery tour but with a flight...
# 24  Like our Inca Discovery tour but with a flight...
# 25  Like our Inca Discovery tour but with a flight...
# 26  Perfect for those looking to experience the re...
# 27  Perfect for those looking to experience the re...
# 28  Perfect for those looking to experience the re...
# 29  We’ll admit it, no one does the Inca Trail qui...
# 30  We’ll admit it, no one does the Inca Trail qui...
# 31  We’ll admit it, no one does the Inca Trail qui...
# 32  There’s more than one way to earn your Peru hi...
# 33  There’s more than one way to earn your Peru hi...
# 34  Peru's ancient Inca Trail is one of the countr...
# 35  Eager to do Peru your own way but still lookin...
# 36  Take the party to new heights in the crisp mou...
# 37  Take the party to new heights in the crisp mou...
# 38  Take the party to new heights in the crisp mou...
# 39  South America rewards those willing to explore...
# 40  South America rewards those willing to explore...
# 41  South America rewards those willing to explore...
# 42  The opportunity to walk Spain's celebrated Cam...
# 43  Take an incredible 10 days to experience the b...
# 44  When you're visiting Portugal and Spain, Moroc...
# 45  Cross two 'stans off your travel map with a 13...
# 46  Ecuador is a small country that packs a punch ...
# 47  Go coast-to-coast from the Pacific to the Maya...
# 48  Just hearing the name Mexico is enough to conj...
# 49  Soak up the incredible contrasts of Mexico on ...
# 50  If you have the time and can’t decide between ...
# 51  If you have the time and can’t decide between ...
# 52  If you have the time and can’t decide between ...
# 53  Stand in awe of the architectural achievement ...
# 54  Now's the time to explore Vietnam on your term...
# 55  Dynamic culture, compelling history, to-die-fo...
# 56  In Portugal, the sun is bright, the food is de...
# 57  Now's the time to explore Cambodia and Vietnam...
# 58  Now's the time to explore Cambodia on your ter...
#
#                     Travel Style Service Level Physical Grading  \
# 0         18-to-Thirtysomethings         Basic        2 - Light
# 1         18-to-Thirtysomethings         Basic        2 - Light
# 2         18-to-Thirtysomethings         Basic      3 - Average
# 3                         Active         Basic  5 - Challenging
# 4                        Classic      Standard        2 - Light
# 5                         Marine      Standard      3 - Average
# 6                        Classic      Standard        2 - Light
# 7                        Classic      Standard        2 - Light
# 8                        Classic      Standard      3 - Average
# 9                        Classic      Standard      3 - Average
# 10                       Classic      Standard        2 - Light
# 11                       Classic      Standard        2 - Light
# 12                       Classic      Standard      3 - Average
# 13                       Classic      Standard      3 - Average
# 14                       Classic      Standard        2 - Light
# 15                        Active      Standard    4 - Demanding
# 16                       Classic      Standard        2 - Light
# 17        18-to-Thirtysomethings         Basic        2 - Light
# 18                       Classic      Standard      3 - Average
# 19                       Classic      Standard      3 - Average
# 20                       Classic      Standard    4 - Demanding
# 21                       Classic      Standard    4 - Demanding
# 22                       Classic      Standard    4 - Demanding
# 23                        Active      Standard    4 - Demanding
# 24                        Active      Standard    4 - Demanding
# 25                        Active      Standard    4 - Demanding
# 26                        Active      Standard    4 - Demanding
# 27                        Active      Standard    4 - Demanding
# 28                        Active      Standard    4 - Demanding
# 29                        Active      Standard    4 - Demanding
# 30                        Active      Standard    4 - Demanding
# 31                        Active      Standard    4 - Demanding
# 32                        Active      Standard    4 - Demanding
# 33                        Active      Standard    4 - Demanding
# 34                        Active      Standard    4 - Demanding
# 35                        Active      Standard    4 - Demanding
# 36        18-to-Thirtysomethings         Basic    4 - Demanding
# 37        18-to-Thirtysomethings         Basic    4 - Demanding
# 38        18-to-Thirtysomethings         Basic    4 - Demanding
# 39        18-to-Thirtysomethings         Basic    4 - Demanding
# 40        18-to-Thirtysomethings         Basic    4 - Demanding
# 41        18-to-Thirtysomethings         Basic    4 - Demanding
# 42                        Active      Standard      3 - Average
# 43        18-to-Thirtysomethings         Basic        2 - Light
# 44        18-to-Thirtysomethings         Basic        2 - Light
# 45                       Classic      Standard      3 - Average
# 46  National Geographic Journeys      Upgraded        2 - Light
# 47                       Classic      Standard        2 - Light
# 48                       Classic      Standard        2 - Light
# 49                       Classic      Standard        2 - Light
# 50        18-to-Thirtysomethings         Basic    4 - Demanding
# 51        18-to-Thirtysomethings         Basic    4 - Demanding
# 52        18-to-Thirtysomethings         Basic    4 - Demanding
# 53                       Classic      Standard        2 - Light
# 54        18-to-Thirtysomethings         Basic        2 - Light
# 55                       Classic      Standard        2 - Light
# 56                       Classic      Standard        2 - Light
# 57        18-to-Thirtysomethings         Basic        2 - Light
# 58        18-to-Thirtysomethings         Basic        2 - Light
#
#                                         Merchandising    Trip Type  \
# 0                                  Planeterra Project  Small Group
# 1                                  Planeterra Project  Small Group
# 2                                  Planeterra Project  Small Group
# 3                         Top Seller Book Your Bubble  Small Group
# 4      Top Seller Planeterra Project Book Your Bubble  Small Group
# 5                                                 NaN  Small Group
# 6      Top Seller Planeterra Project Book Your Bubble  Small Group
# 7   Top Seller Jane Goodall Collection Book Your B...  Small Group
# 8                                                 NaN  Small Group
# 9                                          Top Seller  Small Group
# 10                                   Book Your Bubble  Small Group
# 11                                                NaN  Small Group
# 12     Top Seller Planeterra Project Book Your Bubble  Small Group
# 13                Planeterra Project Book Your Bubble  Small Group
# 14                                   Book Your Bubble  Small Group
# 15                                 Planeterra Project  Small Group
# 16                Planeterra Project Book Your Bubble  Small Group
# 17                                                NaN  Small Group
# 18                     Planeterra Project IDB Project  Small Group
# 19                                 Planeterra Project  Small Group
# 20  Top Seller Planeterra Project IDB Project Awar...  Small Group
# 21  Top Seller Planeterra Project IDB Project Awar...  Small Group
# 22  Top Seller Planeterra Project IDB Project Awar...  Small Group
# 23  Planeterra Project Award Winning Inca Trail Pr...  Small Group
# 24  Planeterra Project Award Winning Inca Trail Pr...  Small Group
# 25  Planeterra Project Award Winning Inca Trail Pr...  Small Group
# 26  Top Seller Planeterra Project Award Winning In...  Small Group
# 27  Top Seller Planeterra Project Award Winning In...  Small Group
# 28  Top Seller Planeterra Project Award Winning In...  Small Group
# 29  Top Seller Planeterra Project Award Winning In...  Small Group
# 30  Top Seller Planeterra Project Award Winning In...  Small Group
# 31  Top Seller Planeterra Project Award Winning In...  Small Group
# 32                Planeterra Project Book Your Bubble  Small Group
# 33                Planeterra Project Book Your Bubble  Small Group
# 34                   Award Winning Inca Trail Program  Small Group
# 35                   Award Winning Inca Trail Program  Small Group
# 36  Planeterra Project Award Winning Inca Trail Pr...  Small Group
# 37  Planeterra Project Award Winning Inca Trail Pr...  Small Group
# 38  Planeterra Project Award Winning Inca Trail Pr...  Small Group
# 39  Top Seller Planeterra Project Award Winning In...  Small Group
# 40  Top Seller Planeterra Project Award Winning In...  Small Group
# 41  Top Seller Planeterra Project Award Winning In...  Small Group
# 42                                   Book Your Bubble  Small Group
# 43                                                NaN  Small Group
# 44                                                NaN  Small Group
# 45                                                NaN  Small Group
# 46                                                NaN  Small Group
# 47                       New Trips Planeterra Project  Small Group
# 48                                          New Trips  Small Group
# 49                       New Trips Planeterra Project  Small Group
# 50  Planeterra Project Award Winning Inca Trail Pr...  Small Group
# 51  Planeterra Project Award Winning Inca Trail Pr...  Small Group
# 52  Planeterra Project Award Winning Inca Trail Pr...  Small Group
# 53                Planeterra Project Book Your Bubble  Small Group
# 54                      Top Seller Planeterra Project  Small Group
# 55                Planeterra Project Book Your Bubble  Small Group
# 56                                   Book Your Bubble  Small Group
# 57                                 Planeterra Project  Small Group
# 58                      Top Seller Planeterra Project  Small Group
#
#    Standard - Adult Standard - Double - D - Adult Standard - Twin - D - Adult
# 0            779.00                           NaN                         NaN
# 1            799.00                           NaN                         NaN
# 2           1049.00                           NaN                         NaN
# 3           1249.00                           NaN                         NaN
# 4            649.00                           NaN                         NaN
# 5               NaN                       1449.00                     1449.00
# 6            579.00                           NaN                         NaN
# 7           1179.00                           NaN                         NaN
# 8           4599.00                           NaN                         NaN
# 9           2799.00                           NaN                         NaN
# 10          1449.00                           NaN                         NaN
# 11          2149.00                           NaN                         NaN
# 12          1259.00                           NaN                         NaN
# 13          2679.00                           NaN                         NaN
# 14          1139.00                           NaN                         NaN
# 15          1299.00                           NaN                         NaN
# 16          1119.00                           NaN                         NaN
# 17           469.00                           NaN                         NaN
# 18          3499.00                           NaN                         NaN
# 19          5059.00                           NaN                         NaN
# 20          2329.00                           NaN                         NaN
# 21          2329.00                           NaN                         NaN
# 22          2329.00                           NaN                         NaN
# 23          1619.00                           NaN                         NaN
# 24          1619.00                           NaN                         NaN
# 25          1619.00                           NaN                         NaN
# 26          1449.00                           NaN                         NaN
# 27          1449.00                           NaN                         NaN
# 28          1449.00                           NaN                         NaN
# 29          1239.00                           NaN                         NaN
# 30          1239.00                           NaN                         NaN
# 31          1239.00                           NaN                         NaN
# 32          1059.00                           NaN                         NaN
# 33          1059.00                           NaN                         NaN
# 34           959.00                           NaN                         NaN
# 35           839.00                           NaN                         NaN
# 36          2269.00                           NaN                         NaN
# 37          2269.00                           NaN                         NaN
# 38          2269.00                           NaN                         NaN
# 39          3749.00                           NaN                         NaN
# 40          3749.00                           NaN                         NaN
# 41          3749.00                           NaN                         NaN
# 42          1229.00                           NaN                         NaN
# 43          1229.00                           NaN                         NaN
# 44          1799.00                           NaN                         NaN
# 45          1929.00                           NaN                         NaN
# 46          1549.00                           NaN                         NaN
# 47          2739.00                           NaN                         NaN
# 48          1169.00                           NaN                         NaN
# 49          1999.00                           NaN                         NaN
# 50          5749.00                           NaN                         NaN
# 51          5749.00                           NaN                         NaN
# 52          5749.00                           NaN                         NaN
# 53           729.00                           NaN                         NaN
# 54           769.00                           NaN                         NaN
# 55          2349.00                           NaN                         NaN
# 56          1029.00                           NaN                         NaN
# 57          1299.00                           NaN                         NaN
# 58           659.00                           NaN                         NaN

# %%
found_itineraries = ['Best of Spain & Portugal', 'Highlights of Portugal']

# %%
summary = ""
for itinerary in found_itineraries:
    filtered_df = df[df['tour_name'] == itinerary]
    summary += f'Itinerary: {filtered_df["tour_name"].values[0]}\n'
    summary += f'Tour description: {filtered_df["tour_description"].values[0]}\n\n'
print(summary)
# Out:
# Itinerary: Best of Spain & Portugal
# tour description: Dynamic culture, compelling history, to-die-for cuisine — the Iberian Peninsula really is a true example of riches for every sense and interest. On this adventure, you’ll soak up the Moorish history of Lisbon and Cordoba, be treated to a lively flamenco performance in Seville, explore the astounding red-clay fortress of the Alhambra, and witness Gaudí’s Barcelona with your own eyes. If that sounds like a lot, be prepared; we’ve only just begun.
#
# Itinerary: Highlights of Portugal
# tour description: In Portugal, the sun is bright, the food is delicious, and the living is easy. Wander the hilly streets of coastal Lisbon, where you can munch on a custard tart while gazing at sun-dappled architecture. Get your fill of history and culture at UNESCO World Heritage Sites like the Monastery of Batalha, Coimbra University, and the picturesque town of Sintra (optional). End the tour in Porto, where the majestic Douro Valley begs for you to lounge back with a glass of port wine in hand. Felicidades! And welcome to Portugal.

# %%
filtered_df = df[df['tour_name'] == 'Best of Spain & Portugal']
filtered_df['visited_countries'].values[0]
# Out:
# 'Spain Portugal'
